# %% [markdown]
# # Step 0 complete!
# You've got Jupyter set up properly, so you should be ready to start the tutorials.  Our resident Python expert (depicted below) will help guide you.
# <br><br>
#
#
#
# <span>
# <img src="attachment:95945d58-9882-436e-8445-b2f73cdcb8ca.png" width="600"/>
# </span>
